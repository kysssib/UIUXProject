# %%
pip install load_dotenv
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from google.colab import output

# 위치 권한 허용 메시지 출력
output.eval_js('navigator.geolocation.getCurrentPosition((position)=>{console.log(position.coords.latitude, position.coords.longitude)})')

#GOOGLE_API_KEY = "AIzaSyDFar-0tkGAWhl93-u0cj54-mTq3daya8Y"

import os
import requests
from dotenv import load_dotenv
import json

load_dotenv(verbose=True)

LOCATION_API_KEY = "AIzaSyDFar-0tkGAWhl93-u0cj54-mTq3daya8Y"

url = f'https://www.googleapis.com/geolocation/v1/geolocate?key={LOCATION_API_KEY}'
data = {
    'considerIp': True,
}

result = requests.post(url, json=data).text

# 문자열을 딕셔너리로 변환
result_dict = json.loads(result)

# 딕셔너리에서 위도와 경도 값 가져오기
google_latitude = result_dict['location']['lat']
google_longitude = result_dict['location']['lng']

print(google_latitude, google_longitude)
# Out:
# 37.09024 -95.712891

# %%
#https://ipstack.com/dashboard
import requests

IPSTACK_KEY = "25233830763e276f00e238fbb1dcaa22"

# ipstack API 호출
response = requests.get(f"http://api.ipstack.com/check?access_key={IPSTACK_KEY}")

# 응답 JSON 파싱
result = response.json()

# 위도, 경도 출력
print(result['latitude'], result['longitude'])
# Out:
# 38.906898498535156 -77.02839660644531

# %%
# 위도와 경도
latitude = google_latitude
longitude = google_longitude
radius = 500

# 가장 가까운 지하철 역 검색
response = requests.get(f"https://maps.googleapis.com/maps/api/place/nearbysearch/json?location={latitude},{longitude}&radius={radius}&type=subway_station&key={LOCATION_API_KEY}")
result = response.json()

print(result)

# 결과에서 가장 가까운 역의 이름 가져오기
if result['status'] == 'ZERO_RESULTS':
    print('가까운 지하철역을 찾을 수 없습니다.')
else:
    subway_name = result['results'][0]['name']
    print(subway_name)
# Out:
# {'html_attributions': [], 'results': [], 'status': 'ZERO_RESULTS'}
# 가까운 지하철역을 찾을 수 없습니다.
# 강남역 2호선

# %%
pip install requests

# %%
#https://developers.kakao.com/console/app/904092

import requests
import json

# 카카오 지도 API 키
KAKAO_API_KEY = "fe85ce059fe1e217d3e2e66ded3668e6"
KAKAO_NATIVE_APP_KEY = "a9913d20d0d79fe92dc1ef1ebaa1690c"
KAKAO_JAVASCRIPT_KEY = "f8e353133815938c664a84cf3f5af459"
KAKAO_ADMIN_KEY = "e8c5d0e7fd115163dac32104343a881c"


latitude = google_latitude
longitude = google_longitude

print(latitude, longitude)

# 가까운 지하철역 검색하기
url = f"https://dapi.kakao.com/v2/local/search/category.json?category_group_code=SW8&x={google_longitude}&y={google_latitude}&radius=2000"
headers = {"Authorization": f"KakaoAK {KAKAO_API_KEY}"}
response = requests.get(url, headers=headers)
result = response.json()

#print(result['documents'])
#for line in result['documents']:
#  print(line)

subway_name = result['documents'][0]['place_name']

print(subway_name)  # 출력 예시: "시청역"
# Out:
# 37.09024 -95.712891
# {'address_name': '서울 강남구 역삼동 858', 'category_group_code': 'SW8', 'category_group_name': '지하철역', 'category_name': '교통,수송 > 지하철,전철 > 수도권2호선', 'distance': '', 'id': '21160803', 'phone': '02-6110-2221', 'place_name': '강남역 2호선', 'place_url': 'http://place.map.kakao.com/21160803', 'road_address_name': '서울 강남구 강남대로 지하 396', 'x': '127.02800140627488', 'y': '37.49808633653005'}
# {'address_name': '서울 마포구 동교동 165', 'category_group_code': 'SW8', 'category_group_name': '지하철역', 'category_name': '교통,수송 > 지하철,전철 > 수도권2호선', 'distance': '', 'id': '21160589', 'phone': '02-6110-2391', 'place_name': '홍대입구역 2호선', 'place_url': 'http://place.map.kakao.com/21160589', 'road_address_name': '서울 마포구 양화로 지하 160', 'x': '126.923778562273', 'y': '37.5568707448873'}
# ...

# %%
subway_name = "화서역"

# 역 이름으로 위도 경도 검색하기
url = f"https://dapi.kakao.com/v2/local/search/keyword.json?query={subway_name}+지하철역"
headers = {"Authorization": f"KakaoAK {KAKAO_API_KEY}"}
response = requests.get(url, headers=headers)
result = response.json()

# 검색 결과가 존재하면 첫 번째 검색 결과의 위도와 경도를 출력
if len(result['documents']) > 0:
  latitude = result['documents'][0]['y']
  longitude = result['documents'][0]['x']
  print(f"위도: {latitude}, 경도: {longitude}")
else:
  print("검색 결과가 존재하지 않습니다.")
# Out:
# 위도: 37.2840016829776, 경도: 126.9896120326472

# %%
#성공한 코드

#https://ipstack.com/dashboard
import requests

IPSTACK_KEY = "25233830763e276f00e238fbb1dcaa22"

# ipstack API 호출
response = requests.get(f"http://api.ipstack.com/check?access_key={IPSTACK_KEY}")

# 응답 JSON 파싱
result = response.json()

# 위도, 경도
latitude = result['latitude']
longitude = result['longitude']

#Google API
LOCATION_API_KEY = "AIzaSyDFar-0tkGAWhl93-u0cj54-mTq3daya8Y"
radius = 2000

# 가장 가까운 지하철 역 검색
response = requests.get(f"https://maps.googleapis.com/maps/api/place/nearbysearch/json?location={latitude},{longitude}&radius={radius}&type=subway_station&key={LOCATION_API_KEY}")
result = response.json()


# 결과에서 가장 가까운 역의 이름 가져오기
if result['status'] == 'ZERO_RESULTS':
    print('가까운 지하철역을 찾을 수 없습니다.')
else:
    subway_name = result['results'][0]['name']
    print(subway_name)
# Out:
# Shaw-Howard Univ Station

# %%
#https://app.ipgeolocation.io/

IPGEOLOCATION_KEY = "a079980098494be7982291ac14d4717a"

import requests

# IP 주소를 이용하여 위도, 경도 가져오기
res = requests.get(f'https://api.ipgeolocation.io/ipgeo?apiKey={IPGEOLOCATION_KEY}')
location = res.json()
latitude = location['latitude']
longitude = location['longitude']

print(latitude, longitude)


#Google API
LOCATION_API_KEY = "AIzaSyDFar-0tkGAWhl93-u0cj54-mTq3daya8Y"
radius = 2000

# 가장 가까운 지하철 역 검색
response = requests.get(f"https://maps.googleapis.com/maps/api/place/nearbysearch/json?location={latitude},{longitude}&radius={radius}&type=subway_station&key={LOCATION_API_KEY}")
result = response.json()


# 결과에서 가장 가까운 역의 이름 가져오기
if result['status'] == 'ZERO_RESULTS':
    print('가까운 지하철역을 찾을 수 없습니다.')
else:
    subway_name = result['results'][0]['name']
    print(subway_name)

# 카카오 지도 API 키
KAKAO_API_KEY = "fe85ce059fe1e217d3e2e66ded3668e6"

# 가까운 지하철역 검색하기
url = f"https://dapi.kakao.com/v2/local/search/category.json?category_group_code=SW8&x={longitude}&y={latitude}&radius={radius}"
headers = {"Authorization": f"KakaoAK {KAKAO_API_KEY}"}
response = requests.get(url, headers=headers)
result = response.json()

if not result['documents']:
    print('가까운 지하철역을 찾을 수 없습니다.')
else:
    subway_name = result['documents'][0]['place_name']
    print(subway_name)
